# %% [markdown]
# ### Table of contents:
#
# * [Download data from CSV](#down)
# * [Data cleaning](#cleaning)
# * [Select companies in cybersecurity](#cyber)
# * [Set limits](#set_limits)
# * [Create graph and dictionaries](#create_graph)
# * [Save graph and dictionaries](#save)
# * [Quick loop](#loop0)

# %%
flag_cybersecurity = True

# %%
import math
import arrow
import ipynb 
import os.path

import json
import pickle
import sys
import random
import operator

import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as ss
import numpy as np

from dotenv import load_dotenv
from networkx.algorithms.bipartite.matrix import biadjacency_matrix
from networkx.algorithms import bipartite
from importlib import reload
from typing import List

# %%
# import functions from py file 

import functions.fun
reload(functions.fun)
from functions.fun import CB_data_cleaning, df_from_api_CB, extract_nodes, extract_data_from_column, field_extraction
from functions.fun import nx_dip_graph_from_pandas, plot_bipartite_graph, filter_dict, check_desc
from functions.fun import extract_classes_company_tech, degree_bip, insert_data_classes

# %%
# import functions from py file 

import functions.fun_meth_reflections
reload(functions.fun_meth_reflections)
from functions.fun_meth_reflections import zero_order_score, Gct_beta, Gtc_alpha, make_G_hat, next_order_score, generator_order_w
from functions.fun_meth_reflections import M_test_triangular, w_stream, find_convergence, rank_df_class, w_star_analytic

# %%
# import classes 

import classes
reload(classes)
# Out:
# <module 'classes' from '/home/anita.mezzetti/bipartite_network/classes.py'>

# %% [markdown]
# ## Download data from CSV <a class="anchor" id="down"></a>

# %%
df_start = pd.read_csv("data/data_cb/organizations.csv")

df_start.head()
# Out:
#                                    uuid             name          type  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd         Wetpaint  organization
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7             Zoho  organization
# 2  5f2b40b8-d1b3-d323-d81a-b7a8e89553d0             Digg  organization
# 3  f4d5ab44-058b-298b-ea81-380e6e9a8eec  Omidyar Network  organization
# 4  df662812-7f97-0b43-9d3e-12f64f504fbb         Facebook  organization
#
#          permalink                                             cb_url  \
# 0         wetpaint   https://www.crunchbase.com/organization/wetpaint
# 1             zoho       https://www.crunchbase.com/organization/zoho
# 2             digg       https://www.crunchbase.com/organization/digg
# 3  omidyar-network  https://www.crunchbase.com/organization/omidya...
# 4         facebook   https://www.crunchbase.com/organization/facebook
#
#        rank           created_at           updated_at          legal_name  \
# 0  158955.0  2007-05-25 13:51:27  2019-06-24 22:19:25                 NaN
# 1    6686.0  2007-05-26 02:30:28  2018-10-27 00:29:49                 NaN
# 2    7793.0  2007-05-26 03:03:23  2018-12-10 10:09:14  Digg Holdings, LLC
# 3  136861.0  2007-05-26 03:21:34  2019-06-19 12:17:48                 NaN
# 4      47.0  2007-05-26 04:22:15  2021-04-14 23:52:25      Facebook, Inc.
#
#               roles  ...         phone  \
# 0           company  ...  206-859-6300
# 1  investor,company  ...           NaN
# 2           company  ...  877-342-7222
# 3          investor  ...  650.482.2500
# 4  investor,company  ...           NaN
#
#                              facebook_url  \
# 0       https://www.facebook.com/Wetpaint
# 1            http://www.facebook.com/zoho
# 2            http://www.facebook.com/digg
# 3  http://www.facebook.com/OmidyarNetwork
# 4      https://www.facebook.com/facebook/
#
#                                         linkedin_url  \
# 0          https://www.linkedin.com/company/wetpaint
# 1  http://www.linkedin.com/company/zoho-corporati...
# 2               http://www.linkedin.com/company/digg
# 3              http://www.linkedin.com/company/22806
# 4           http://www.linkedin.com/company/facebook
#
#                          twitter_url  \
# 0     https://twitter.com/wetpainttv
# 1            http://twitter.com/zoho
# 2            http://twitter.com/digg
# 3  http://twitter.com/OmidyarNetwork
# 4       https://twitter.com/facebook
#
#                                             logo_url alias1 alias2 alias3  \
# 0  https://res.cloudinary.com/crunchbase-producti...    NaN    NaN    NaN
# 1  https://res.cloudinary.com/crunchbase-producti...    NaN    NaN    NaN
# 2  https://res.cloudinary.com/crunchbase-producti...    NaN    NaN    NaN
# 3  https://res.cloudinary.com/crunchbase-producti...    NaN    NaN    NaN
# 4  https://res.cloudinary.com/crunchbase-producti...    NaN    NaN    NaN
#
#   primary_role num_exits
# 0      company       NaN
# 1      company       1.0
# 2      company       NaN
# 3     investor      38.0
# 4      company       NaN
#
# [5 rows x 41 columns]

# %%
df_start.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'legal_name', 'roles', 'domain', 'homepage_url',
#        'country_code', 'state_code', 'region', 'city', 'address',
#        'postal_code', 'status', 'short_description', 'category_list',
#        'category_groups_list', 'num_funding_rounds', 'total_funding_usd',
#        'total_funding', 'total_funding_currency_code', 'founded_on',
#        'last_funding_on', 'closed_on', 'employee_count', 'email', 'phone',
#        'facebook_url', 'linkedin_url', 'twitter_url', 'logo_url', 'alias1',
#        'alias2', 'alias3', 'primary_role', 'num_exits'],
#       dtype='object')

# %% [markdown]
# ## Data Cleaning <a class="anchor" id="cleaning"></a>
#
# We decide to use as key the name. For the future, it would be better to use the uuid
#
# - `df_start`: dataset before cleaning
# - `df` : datsety after cleaning

# %%
# we create the lists needed as input in the function to clean the data

to_drop = [
    'type',
    'permalink',
    'cb_url',   
    'created_at',
    'domain',
    'address',
    'state_code',
    'updated_at',
    'legal_name',
    'roles',
    'postal_code',
    'homepage_url',
    'num_funding_rounds',
    'total_funding_currency_code',
    'phone',
    'email',
    'num_exits',
    'alias2',
    'alias3',
    'num_exits',
    'logo_url',
    'alias1',
    'last_funding_on',
    'twitter_url',
    'facebook_url'
]

# to_rename = { 'category_groups_list': 'category_groups' }
to_rename = { 'category_list': 'category_groups' }

drop_if_nan = [
    'category_groups',
    'rank',
    'short_description'
]

to_check_double = {}

sort_by = "rank"

# %%
# clean data: from df_start to df
df = CB_data_cleaning(df_start, to_drop, to_rename, to_check_double, drop_if_nan, sort_by)

# %%
# show cleaned dataset
df.head()
# Out:
#                                         uuid       name  rank country_code  \
# 1178    74a20af3-f4dd-6188-de60-c4ee6cd0ca4a  Ant Group   1.0          CHN
# 4042    022417b5-4980-6c54-0f3c-6736bbbb1a5e    Spotify   2.0          SWE
# 349     468bef9f-2f50-590e-6e78-62e3adb05aa1       Citi   3.0          USA
# 211260  a40d0a1f-f32c-a1e9-1bbd-a10bb0eca2e7  Deliveroo   4.0          GBR
# 621119  00daca16-8311-454b-84e0-24a40d16be9c     Antler   5.0          SGP
#
#                 region       city     status  \
# 1178          Zhejiang   Hangzhou  operating
# 4042    Stockholms Lan  Stockholm        ipo
# 349           New York   New York        ipo
# 211260         England     London        ipo
# 621119  Central Region  Singapore  operating
#
#                                         short_description  \
# 1178    Ant Group strives to enable all consumers and ...
# 4042    Spotify is a commercial music streaming servic...
# 349     Citigroup is a diversified financial services ...
# 211260  Deliveroo is an online food delivery service t...
# 621119  Antler is a global early-stage venture capital...
#
#                                           category_groups  \
# 1178          Banking,Financial Services,FinTech,Payments
# 4042    Audio,Cloud Computing,Music,Music Streaming,Vi...
# 349     Banking,Credit Cards,Financial Services,Wealth...
# 211260  Delivery,Food and Beverage,Food Delivery,Same ...
# 621119                                    Venture Capital
#
#                                      category_groups_list  total_funding_usd  \
# 1178    Financial Services,Lending and Investments,Pay...       2.200000e+10
# 4042    Content and Publishing,Internet Services,Media...       2.085425e+09
# 349     Financial Services,Lending and Investments,Pay...       8.700000e+09
# 211260  Administrative Services,Food and Beverage,Tran...       1.712683e+09
# 621119         Financial Services,Lending and Investments       7.800000e+07
#
#         total_funding  founded_on closed_on employee_count  \
# 1178     2.200000e+10  2014-10-01       NaN     5001-10000
# 4042     2.085425e+09  2006-04-23       NaN     5001-10000
# 349      8.700000e+09  1998-10-08       NaN         10000+
# 211260   1.712683e+09  2012-01-01       NaN     5001-10000
# 621119   7.800000e+07  2017-01-01       NaN        101-250
#
#                                           linkedin_url primary_role
# 1178        https://www.linkedin.com/company/antgroup/      company
# 4042           http://www.linkedin.com/company/spotify      company
# 349              https://www.linkedin.com/company/citi     investor
# 211260      https://www.linkedin.com/company/deliveroo      company
# 621119  https://www.linkedin.com/company/antlerglobal/     investor

# %%
df.columns
# Out:
# Index(['uuid', 'name', 'rank', 'country_code', 'region', 'city', 'status',
#        'short_description', 'category_groups', 'category_groups_list',
#        'total_funding_usd', 'total_funding', 'founded_on', 'closed_on',
#        'employee_count', 'linkedin_url', 'primary_role'],
#       dtype='object')

# %%
# convert category_groups to list

def convert_to_list(string):
    li = list(string.split(","))
    return li
  
if type(df["category_groups"][df.index[0]]) != list:
    df["category_groups"] = [convert_to_list(x) for x in df["category_groups"]]

# %%
len(df)
# Out:
# 1254665

# %% [markdown]
# ### Select companies in cybersecurity <a class="anchor" id="cyber"></a>
#
#
# We decide to select only companies that work in the cybersecurity field. The algorithm is easily extendible to any field: we only have to change the _field_words_ list word

# %%
flag_cybersecurity
# Out:
# True

# %%
if flag_cybersecurity == True:
    df, flag_cybersecurity = field_extraction('cybersecurity', df)
else:
    df, flag_cybersecurity = field_extraction('medicine', df)

# %%
df.head()
# Out:
#                                         uuid        name   rank country_code  \
# 397698  b99936db-3b9f-4397-e03b-7ddb70c2dc00    OneTrust  107.0          USA
# 362482  655ff5a2-33d2-dfe5-af13-20866a58a5c0       BigID  152.0          USA
# 75057   3e9d5f7e-7301-b645-66af-eb756892af3a     Zscaler  170.0          USA
# 740558  7ca00768-e6a1-4a58-9aff-871a46bf8971     AppOmni  280.0          USA
# 21622   8e3a72ba-b0af-f535-615e-477ce5ba119e  SimpliSafe  323.0          USA
#
#                region           city     status  \
# 397698        Georgia        Atlanta  operating
# 362482       New York       New York  operating
# 75057      California       San Jose        ipo
# 740558     California  San Francisco  operating
# 21622   Massachusetts         Boston   acquired
#
#                                         short_description  \
# 397698  OneTrust helps companies manage privacy, secur...
# 362482  BigID is a data intelligence company developin...
# 75057   Zscaler is a global cloud-based information se...
# 740558  AppOmni is a SaaS security management solution...
# 21622   SimpliSafe is a home security solutions provid...
#
#                                           category_groups  \
# 397698   [Compliance, Privacy, Risk Management, Software]
# 362482  [Artificial Intelligence, Big Data, Cyber Secu...
# 75057   [Cloud Security, Cyber Security, Enterprise So...
# 740558  [Cloud Management, Cloud Security, Cyber Secur...
# 21622   [Consumer Electronics, Security, Sensor, Smart...
#
#                                      category_groups_list  total_funding_usd  \
# 397698  Privacy and Security,Professional Services,Sof...        920000000.0
# 362482  Artificial Intelligence,Data and Analytics,Inf...        246099999.0
# 75057   Information Technology,Privacy and Security,So...        148000000.0
# 740558  Information Technology,Internet Services,Priva...         53000000.0
# 21622   Consumer Electronics,Hardware,Privacy and Secu...        187000000.0
#
#         total_funding  founded_on closed_on employee_count  \
# 397698    920000000.0  2016-01-01       NaN      1001-5000
# 362482    246099999.0  2016-02-01       NaN        101-250
# 75057     148000000.0  2008-01-01       NaN      1001-5000
# 740558     53000000.0  2018-01-01       NaN         51-100
# 21622     187000000.0  2006-01-01       NaN       501-1000
#
#                                       linkedin_url primary_role
# 397698   https://www.linkedin.com/company/onetrust      company
# 362482      https://www.linkedin.com/company/bigid      company
# 75057    https://www.linkedin.com/company/zscaler/      company
# 740558    https://www.linkedin.com/company/appomni      company
# 21622   http://www.linkedin.com/company/simplisafe      company

# %%
df['short_description'].values
# Out:
# array(['OneTrust helps companies manage privacy, security and governance requirements in a regulatory environment that constantly changes.',
#        'BigID is a data intelligence company developing software that helps companies secure customer data and satisfy privacy regulations.',
#        'Zscaler is a global cloud-based information security company that enabling secure digital transformation for a mobile and cloud first world.',
#        ...,
#        'At Buffums Safe and Lock Service, all of our locksmiths in Camarillo CA complete the Certified Department of Defense Lock Program X-09.',
#        'The Taxperts is to provide their clients quality service with professionalism, communication, and integrity.',
#        'Wayne Alarm strives to provide the best security and life safety systems available.'],
#       dtype=object)

# %%
flag_cybersecurity
# Out:
# True

# %% [markdown]
# ### Create Companies and Technologies classes

# %% [markdown]
# #### Ranking
#
# I personally appreciate the ranking that you provide for each company. However, I did not quite understand what's the magic behind it. Is there any chance to get some more insight/details, also considering that we do have an NDA in place?
#
# - Crunchbase rank uses Crunchbase’s intelligent algorithms to score and rank entities (e.g. Company, People, Investors, etc.).
# - The algorithms take into account many different variables; ranging from funding events, the entity’s strength of relationships with other entities in the Crunchbase ecosystem, the level of engagement from our website, news articles, and acquisitions.
#
#     - A company’s Rank is fluid and subject to rising and decaying over time with time-sensitive events. Events such as product launches, funding events, leadership changes, and news affect a company’s Crunchbase Rank.
#
#
# - The Crunchbase rank shows where an entity falls in the Crunchbase database relative to all other entities in that entity type (i.e. if searching for companies, you will see where a specific company ranks relative to all other companies). An entity with a Crunchbase Rank of 1 has the highest rank relative to all other entities of that type.
#
# I would also suggest leveraging our Trend Score - 7 Day, 30 Day, 90 Day (e.g. Company, People, Investors, etc.)
#
# - While Rank shows context, Crunchbase Trend Score demonstrates activity. A company’s rank will change based on activity (fundraising, news, etc.) and Trend Score is an indicator of how much their rank is changing at any given time.
# - Crunchbase Trend Score tracks the fluctuations in Rank. As a company’s rank changes, so do its Trend Score.
# - Trend Score measures the rate of a company’s activity on a 20-point (+10 <-> -10) scale. Scores closer to +10 mean it’s moving up in rank much faster compared to their peers. Scores closer to -10 mean it’s moving down.
# - For example, a company that announces its first funding round will likely experience a jump in its Rank, pushing its Trend Score up as its page views, article counts, funding amount, team members, etc., begin to increase.

# %% [markdown]
# ## Set limits <a class="anchor" id="set_limits"></a>
#
# In case we want to set a limits to the number of companies. Usually the next cell should be commented

# %%
len(df)
# Out:
# 3484

# %%
# limits in cybersecurity
# limits = [10, 100, 500, 1000, 1500, 2000, 2443]

# limits in medicine: total 25293 companies
limits = [500, 1500, 2000, 3000]

# %%
#df_limited = df[:100]

# %% [markdown]
# ## Create graph and dictionaries <a class="anchor" id="create_graph"></a>

# %%
# Extracts the dictionaries of Companies and Technologies from the dataset and create the network
[dict_companies, dict_tech, B] = extract_classes_company_tech(df_limited)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-e5d0862f52b3> in <module>
#       1 # Extracts the dictionaries of Companies and Technologies from the dataset and create the network
# ----> 2 [dict_companies, dict_tech, B] = extract_classes_company_tech(df_limited)
#
# NameError: name 'df_limited' is not defined

# %%
print(f"We have {len(dict_companies)} companies and {len(dict_tech)} technologies")

# %% [markdown]
# ## Save dictionaries and network <a class="anchor" id="save"></a>

# %%
# Save dictionaries in a pickle files

if flag_cybersecurity==False: # all fields
    name_file_com = "savings/classes/dict_companies_" + str(len(dict_companies)) + ".pickle"
    name_file_tech = "savings/classes/dict_tech_" + str(len(dict_tech)) + ".pickle"
else: # only companies in cybersecurity
    name_file_com = "savings/classes/dict_companies_cybersecurity_" + str(len(dict_companies)) + ".pickle"
    name_file_tech = "savings/classes/dict_tech_cybersecurity_" + str(len(dict_tech)) + ".pickle"

# companies
with open(name_file_com, "wb") as f:
    pickle.dump(dict_companies, f)

#technologies
with open(name_file_tech, "wb") as f:
    pickle.dump(dict_tech, f)

# %%
# Save the bipartite graph as gpickle:

if flag_cybersecurity==False: # all fields
    name_file_graph = 'savings/networks/comp_' + str(len(dict_companies)) + '_tech_' + str(len(dict_tech)) + '.gpickle'                                     
else: # only companies in cybersecurity
    name_file_graph = 'savings/networks/cybersecurity_comp_'+ str(len(dict_companies)) + '_tech_' + str(len(dict_tech)) + '.gpickle'
                                                       
nx.write_gpickle(B, name_file_graph)

# %% [markdown]
# ## Quick loop  <a class="anchor" id="loop0"></a>
#
# With quick loop, we mean that we do all the step of the previous sections, in order to update the dictionaries, for all size, in only one loop.
#
# In this part, you won't see many comments because everything has been already explained before :)

# %%
limits = [500, 1000, 1499, 1999, 2442]
flag_cybersecurity = True

# %%
for i in limits:
    df_limited = df[:i]
    [dict_companies, dict_tech, B] = extract_classes_company_tech(df_limited)
    print(f"We have {len(dict_companies)} companies and {len(dict_tech)} technologies")
    
    # Save dictionaries in a pickle files

    if flag_cybersecurity==False: # all fields
        name_file_com = "savings/classes/dict_companies_" + str(len(dict_companies)) + ".pickle"
        name_file_tech = "savings/classes/dict_tech_" + str(len(dict_tech)) + ".pickle"
    else: # only companies in cybersecurity
        name_file_com = "savings/classes/dict_companies_cybersecurity_" + str(len(dict_companies)) + ".pickle"
        name_file_tech = "savings/classes/dict_tech_cybersecurity_" + str(len(dict_tech)) + ".pickle"

    # companies
    with open(name_file_com, "wb") as f:
        pickle.dump(dict_companies, f)

    #technologies
    with open(name_file_tech, "wb") as f:
        pickle.dump(dict_tech, f)
        
    if flag_cybersecurity==False: # all fields
        name_file_graph = 'savings/networks/comp_' + str(len(dict_companies)) + '_tech_' + str(len(dict_tech)) + '.gpickle'                                     
    else: # only companies in cybersecurity
        name_file_graph = 'savings/networks/cybersecurity_comp_'+ str(len(dict_companies)) + '_tech_' + str(len(dict_tech)) + '.gpickle'

    nx.write_gpickle(B, name_file_graph)
# Out:
# Atlanta, Fulton County, Georgia, United States
# New York, United States
# San Jose, Santa Clara County, California, United States
# San Francisco, San Francisco City and County, San Francisco, California, United States
# Boston, Suffolk County, Massachusetts, United States
# San Francisco, San Francisco City and County, San Francisco, California, United States
# San Jose, Santa Clara County, California, United States
# Schaffhausen, Schweiz/Suisse/Svizzera/Svizra
# Dallas, Dallas County, Texas, United States
# San Mateo County, California, United States
# London, City of Westminster, England, SW1A 2DX, United Kingdom
# Redwood City, San Mateo County, California, United States
# Toronto, Golden Horseshoe, Ontario, Canada
# دبي, الإمارات العربية المتحدة
# San Ramon, Contra Costa County, California, United States
# Boston, Suffolk County, Massachusetts, United States
# Tempe, Maricopa County, Arizona, United States
# San Francisco, San Francisco City and County, San Francisco, California, United States
# Philadelphia, Philadelphia County, Pennsylvania, United States
# New York, United States
# Atlanta, Fulton County, Georgia, United States
# Schaumburg, Schaumburg Township, Cook County, Illinois, United States
# New York, United States
# New York, United States
# Redwood City, San Mateo County, California, United States
# Akron, Summit County, Ohio, United States
# Kansas City, Jackson County, Missouri, United States
# Dallas, Dallas County, Texas, United States
# Culver City, California, United States
# Houston, Harris County, Texas, United States
# Chippendale, Sydney, Council of the City of Sydney, New South Wales, 2008, Australia
# San Diego, San Diego County, California, United States
# New York, United States
# Mountain View, Santa Clara County, California, United States
# University of Maryland, College Park, University Boulevard East, Berwyn, College Park, Prince George's County, Maryland, 20740, United States
# Stockholm, Stockholms kommun, Stockholms län, 111 29, Sverige
# Los Angeles, California, United States
# Chicago, Cook County, Illinois, United States
# San Jose, Santa Clara County, California, United States
# 明星西點咖啡, 5, 武昌街一段, 光復里, 中正區, 城內, 臺北市, 10044, 臺灣
# San Diego, San Diego County, California, United States
# New York, United States
# Washington, District of Columbia, United States
# Menlo Park, San Mateo County, California, United States
# Atlanta, Fulton County, Georgia, United States
# San Jose, Santa Clara County, California, United States
# Austin, Travis County, Texas, United States
# Pittsburgh, Allegheny County, Pennsylvania, United States
# Houston, Harris County, Texas, United States
# San Diego, San Diego County, California, United States
# Alpharetta, Fulton County, Georgia, United States
# Ramhal 4, Tel-Aviv, 4, רמח"ל, תל אביב - יפו, לב תל-אביב, תל אביב-יפו, נפת תל אביב, מחוז תל אביב, no, ישראל
# Chicago, Cook County, Illinois, United States
# San Francisco, San Francisco City and County, San Francisco, California, United States
# Boulder, Boulder County, Colorado, United States
# Herndon, McNair, Fairfax County, Virginia, United States
# Zürich, Bezirk Zürich, Zürich, Schweiz/Suisse/Svizzera/Svizra
# Provo, Utah County, Utah, United States
# Ramhal 4, Tel-Aviv, 4, רמח"ל, תל אביב - יפו, לב תל-אביב, תל אביב-יפו, נפת תל אביב, מחוז תל אביב, no, ישראל
# Los Gatos, Santa Clara County, California, United States
# Columbus, Franklin County, Ohio, United States
# Québec, Québec (Agglomération), Capitale-Nationale, Québec, Canada
# Houston, Harris County, Texas, United States
# הרצליה, נפת תל אביב, מחוז תל אביב, ישראל
# New York, United States
# Ramhal 4, Tel-Aviv, 4, רמח"ל, תל אביב - יפו, לב תל-אביב, תל אביב-יפו, נפת תל אביב, מחוז תל אביב, no, ישראל
# Dallas, Dallas County, Texas, United States
# San Francisco, San Francisco City and County, San Francisco, California, United States
# South Jordan, Salt Lake County, Utah, United States
# Bellevue, King County, Washington, United States
# Greenwood Village, Arapahoe County, Colorado, United States
# کراچی, سندھ, پاکستان
# San Francisco, San Francisco City and County, San Francisco, California, United States
# Waterloo, Region of Waterloo, Southwestern Ontario, Ontario, Canada
# Lake Mary, Seminole County, Florida, United States
# McLean, Fairfax County, Virginia, United States
# Ramhal 4, Tel-Aviv, 4, רמח"ל, תל אביב - יפו, לב תל-אביב, תל אביב-יפו, נפת תל אביב, מחוז תל אביב, no, ישראל
# San Francisco, San Francisco City and County, San Francisco, California, United States
# Encino, Los Angeles, California, 91316-3402, United States
# Sydney, New South Wales, Australia
# Köln, Nordrhein-Westfalen, Deutschland
# Brescia, Lombardia, Italia
# Genève, Grand Genève, Genève, Schweiz/Suisse/Svizzera/Svizra
# Pittsburgh, Allegheny County, Pennsylvania, United States
# Mountain View, Santa Clara County, California, United States
# West Chester, Chester County, Pennsylvania, 19383, United States
# London, City of Westminster, England, SW1A 2DX, United Kingdom
# Vancouver, District of North Vancouver, Metro Vancouver Regional District, British Columbia, Canada
# Boston, Suffolk County, Massachusetts, United States
# רמת גן, נפת תל אביב, מחוז תל אביב, ישראל
# Kirkland, King County, Washington, United States
# Atlanta, Fulton County, Georgia, United States
# Palo Alto, Santa Clara County, California, United States
# Philadelphia, Philadelphia County, Pennsylvania, United States
# Stockholm, Stockholms kommun, Stockholms län, 111 29, Sverige
# Sydney, Cape Breton Regional Municipality, Cape Breton County, Nova Scotia, Canada
# New York, United States
# Auburn, Victoria Road, Hawthorn East, Melbourne, City of Boroondara, Victoria, 3123, Australia
# Zoetermeer, Zuid-Holland, Nederland
# Newberg, Yamhill County, Oregon, United States
# Zaragoza, Aragón, España
# Fort Worth, Tarrant County, Texas, United States
# Houston, Harris County, Texas, United States
# Newark, New Castle County, Delaware, United States
# Dayton, Montgomery County, Ohio, United States
# Toronto, Golden Horseshoe, Ontario, Canada
# Houston, Harris County, Texas, United States
# Worsley Farm, Charnock Richard, Chorley, Lancashire, North West England, England, United Kingdom
# Oslo, Main Station Hallway, Sjøtomta, Sentrum, Oslo, 0050, Norge
# Ahmedabad, Ahmadabad City Taluka, Ahmedabad District, Gujarat, 380001, India
# Bengaluru, Bangalore North, Bangalore Urban, Karnataka, India
# Silver Spring, Montgomery County, Maryland, United States
# Toronto, Golden Horseshoe, Ontario, Canada
# Noida, Dadri, Gautam Buddha Nagar, Uttar Pradesh, 201301, India
# Austin, Travis County, Texas, United States
# Scottsdale, Maricopa County, Arizona, United States
# Midview City, Bishan, Central, Singapore
# Scottsdale, Maricopa County, Arizona, United States
# North Charleston, Charleston County, South Carolina, United States
# Roswell, Fulton County, Georgia, United States
# Palo Alto, Santa Clara County, California, United States
# Hendrik-Ido-Ambacht, Zuid-Holland, Nederland
# San Antonio, Bexar County, Texas, United States
# Texas, Dorchester County, South Carolina, 29447, United States
# Columbus, Franklin County, Ohio, United States
# Flint, Genesee County, Michigan, United States
# Malibu, California, 90265-4797, United States
# West Bridgford, Rushcliffe, Nottinghamshire, East Midlands, England, United Kingdom
# Pune City, Pune District, Maharashtra, India
# Zürich, Bezirk Zürich, Zürich, Schweiz/Suisse/Svizzera/Svizra
# Brummen, Gelderland, Nederland
# Selangor, Persiaran Kewajipan, UEP Subang Jaya, Puchong, Subang Jaya, Petaling, Selangor, 47200, Malaysia
# Chicago, Cook County, Illinois, United States
# Emeryville, Alameda County, California, 94608, United States
# Omaha, Douglas County, Nebraska, United States
# Houston, Harris County, Texas, United States
# Rochester, Monroe County, New York, United States
# Paris, Île-de-France, France métropolitaine, France
# Stockholm, Stockholms kommun, Stockholms län, 111 29, Sverige
# Philadelphia, Philadelphia County, Pennsylvania, United States
# Largo, Pinellas County, Florida, United States
# New York, United States
# Zürich, Bezirk Zürich, Zürich, Schweiz/Suisse/Svizzera/Svizra
# Roma, Roma Capitale, Lazio, Italia
# Austin, Travis County, Texas, United States
# San Diego, San Diego County, California, United States
# 那覇市, 沖縄県, 900-8585, 日本
# Jacksonville, Duval County, Florida, United States
# Dallas, Dallas County, Texas, United States
# Mājro, Ṃajeḷ
# Menlo Park, San Mateo County, California, United States
# Thành phố Hồ Chí Minh, Việt Nam
# San Luis Obispo County, California, United States
# St. John's, Newfoundland, Newfoundland and Labrador, Canada
# Finland, Lake County, Minnesota, 55603, United States
# University of California, Berkeley, La Loma Steps, Northside, Berkeley, Alameda County, California, 94708, United States
# Zürich, Bezirk Zürich, Zürich, Schweiz/Suisse/Svizzera/Svizra
# Saarbrücken, Regionalverband Saarbrücken, Saarland, Deutschland
# Regensburg, Bayern, Deutschland
# Southampton, Upper Southampton Township, Bucks County, Pennsylvania, 19407, United States
# Toronto, Golden Horseshoe, Ontario, Canada
# Bologna, Emilia-Romagna, Italia
# Utrecht, Nederland
# Bellefontaine, Lake Township, Logan County, Ohio, 43311, United States
# أكودة, أكودة الشرقية, معتمدية أكودة, ولاية سوسة, 4022, تونس
# Tallinn, Harju maakond, Eesti
# San Antonio, Bexar County, Texas, United States
# Centennial, Arapahoe County, Colorado, United States
# Sunrise, Broward County, Florida, United States
# Amsterdam, Noord-Holland, Nederland
# Cranston, Providence County, Rhode Island, United States
# Espoo, Helsingin seutukunta, Uusimaa, Etelä-Suomen aluehallintovirasto, Manner-Suomi, Suomi / Finland
# Vancouver, District of North Vancouver, Metro Vancouver Regional District, British Columbia, Canada
# Boston, Suffolk County, Massachusetts, United States
# Zürich, Bezirk Zürich, Zürich, Schweiz/Suisse/Svizzera/Svizra
# London, City of Westminster, England, SW1A 2DX, United Kingdom
# Stockport, Station Road, Edgeley, Stockport, Greater Manchester, North West England, England, SK3 9DY, United Kingdom
# Ramhal 4, Tel-Aviv, 4, רמח"ל, תל אביב - יפו, לב תל-אביב, תל אביב-יפו, נפת תל אביב, מחוז תל אביב, no, ישראל
# Chattanooga, Hamilton County, Tennessee, United States
# Carson City, Nevada, 89701-4763, United States
# Fort Lauderdale, Broward County, Florida, United States
# Phoenix, Maricopa County, Arizona, United States
# Lebanon, Boone County, Indiana, 46052, United States
# Cagayan, Santa Ana Villas, Pandacan, Sixth District, Manila, Capital District, Metro Manila, 1009, Philippines
# ঢাকা, Chanpara Bazar, ঢাকা জেলা, ঢাকা বিভাগ, 1230, বাংলাদেশ
# Dayton, Montgomery County, Ohio, United States
# Spring, Harris County, Texas, 77373, United States
# Zaltbommel, Gelderland, Nederland
# Westlake, Cuyahoga County, Ohio, United States
# City of Saint Louis, Missouri, United States
# National Environment Agency (Central Region), 4545, Jalan Bukit Merah, Bukit Merah, Central, 159466, Singapore
# Emeryville, Alameda County, California, 94608, United States
# Lenexa, Johnson County, Kansas, United States
# Fremont, Alameda County, California, United States
# Sacramento, Sacramento County, California, United States
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/miniconda3/envs/arma/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/miniconda3/envs/arma/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/miniconda3/envs/arma/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# ~/miniconda3/envs/arma/lib/python3.8/http/client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# ~/miniconda3/envs/arma/lib/python3.8/http/client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# ~/miniconda3/envs/arma/lib/python3.8/http/client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# ~/miniconda3/envs/arma/lib/python3.8/socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# ~/miniconda3/envs/arma/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# ~/miniconda3/envs/arma/lib/python3.8/ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# ~/miniconda3/envs/arma/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~/miniconda3/envs/arma/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     448             raise
#
# ~/miniconda3/envs/arma/lib/python3.8/site-packages/urllib3/connectionpool.py in _raise_timeout(self, err, url, timeout_value)
#     335         if isinstance(err, SocketTimeout):
# --> 336             raise ReadTimeoutError(
#     337                 self, url, "Read timed out. (read timeout=%s)" % timeout_value
#
# ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/miniconda3/envs/arma/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/miniconda3/envs/arma/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# ~/miniconda3/envs/arma/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# ~/miniconda3/envs/arma/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/miniconda3/envs/arma/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     572         if new_retry.is_exhausted():
# --> 573             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     574
#
# MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Santiago%2C+Region+Metropolitana&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~/miniconda3/envs/arma/lib/python3.8/site-packages/geopy/adapters.py in _request(self, url, timeout, headers)
#     386         try:
# --> 387             resp = self.session.get(url, timeout=timeout, headers=headers)
#     388         except Exception as error:
#
# ~/miniconda3/envs/arma/lib/python3.8/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     554         kwargs.setdefault('allow_redirects', True)
# --> 555         return self.request('GET', url, **kwargs)
#     556
#
# ~/miniconda3/envs/arma/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#
# ~/miniconda3/envs/arma/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#
# ~/miniconda3/envs/arma/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#
# ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Santiago%2C+Region+Metropolitana&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# GeocoderUnavailable                       Traceback (most recent call last)
# <ipython-input-29-7dd26331d999> in <module>
#       1 for i in limits:
#       2     df_limited = df[:i]
# ----> 3     [dict_companies, dict_tech, B] = extract_classes_company_tech(df_limited)
#       4     print(f"We have {len(dict_companies)} companies and {len(dict_tech)} technologies")
#       5
#
# ~/bipartite_network/functions/fun.py in extract_classes_company_tech(df)
#     253         else:
#     254             str_place = row['city'] + ', ' + row['region'] #+ ', ' +  row['country_code']
# --> 255             location = geolocator.geocode(str_place) # coversion to conventional address (valid for the next command)
#     256
#     257             print(location)
#
# ~/miniconda3/envs/arma/lib/python3.8/site-packages/geopy/geocoders/nominatim.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     295         logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     296         callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297         return self._call_geocoder(url, callback, timeout=timeout)
#     298
#     299     def reverse(
#
# ~/miniconda3/envs/arma/lib/python3.8/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, callback, timeout, is_json, headers)
#     358         try:
#     359             if is_json:
# --> 360                 result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     361             else:
#     362                 result = self.adapter.get_text(url, timeout=timeout, headers=req_headers)
#
# ~/miniconda3/envs/arma/lib/python3.8/site-packages/geopy/adapters.py in get_json(self, url, timeout, headers)
#     375
#     376     def get_json(self, url, *, timeout, headers):
# --> 377         resp = self._request(url, timeout=timeout, headers=headers)
#     378         try:
#     379             return resp.json()
#
# ~/miniconda3/envs/arma/lib/python3.8/site-packages/geopy/adapters.py in _request(self, url, timeout, headers)
#     397                     raise GeocoderServiceError(message)
#     398                 else:
# --> 399                     raise GeocoderUnavailable(message)
#     400             elif isinstance(error, requests.Timeout):
#     401                 raise GeocoderTimedOut("Service timed out")
#
# GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Santiago%2C+Region+Metropolitana&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
